# %%
# Machine Learning Models

# %%
# Data => x , y
# x => x_train , x_test
# y => y_train , y_test

# for model training
# model.fit(x_train , y_train)

# for model prediction
# y_pred = model.predict(x_test)
# Model Accuracy
# metrics_score(y_test , y_pred)

# %%
# Models => 
# 1. Supervised ML Model => Labeled data train => LinearRegression, LogisticRegression , Decision Tree , RandomForest etc.
# 2. UnSupervised ML Model => Unlabelled data train => Kmeans , PCA

# %% [markdown]
# # Linear Regression

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\Anmol Hemani\\OneDrive\\Desktop\\Jupyter\\Test\\insurance.csv")

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb = LabelEncoder()

# %%
df['sex'] = lb.fit_transform(df['sex'])
df['smoker'] = lb.fit_transform(df['smoker'])
df['region'] = lb.fit_transform(df['region'])

# %%
df.head()
# Out:
#    age  sex     bmi  children  smoker  region      charges
# 0   19    0  27.900         0       1       3  16884.92400
# 1   18    1  33.770         1       0       2   1725.55230
# 2   28    1  33.000         3       0       2   4449.46200
# 3   33    1  22.705         0       0       1  21984.47061
# 4   32    1  28.880         0       0       1   3866.85520

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
x = df.drop(columns = ['charges'])
y = df['charges']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train , y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test , y_pred)
# Out:
# 0.7833463107364539

# %% [markdown]
# # Logistic Regression

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\Anmol Hemani\\OneDrive\\Desktop\\Jupyter\\Test\\covid_toy.csv")

# %%
df.head()
# Out:
#    age  gender  fever cough     city has_covid
# 0   60    Male  103.0  Mild  Kolkata        No
# 1   27    Male  100.0  Mild    Delhi       Yes
# 2   42    Male  101.0  Mild    Delhi        No
# 3   31  Female   98.0  Mild  Kolkata        No
# 4   65  Female  101.0  Mild   Mumbai        No

# %%
df.isnull().sum()
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

# %%
si = SimpleImputer()

# %%
df['fever'] = si.fit_transform(df[['fever']])

# %%
df.isnull().sum()
# Out:
# age          0
# gender       0
# fever        0
# cough        0
# city         0
# has_covid    0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df['gender'] = le.fit_transform(df['gender'])
df['cough'] = le.fit_transform(df['cough'])
df['city'] = le.fit_transform(df['city'])
df['has_covid'] = le.fit_transform(df['has_covid'])

# %%
df.head()
# Out:
#    age  gender  fever  cough  city  has_covid
# 0   60       1  103.0      0     2          0
# 1   27       1  100.0      0     1          1
# 2   42       1  101.0      0     1          0
# 3   31       0   98.0      0     2          0
# 4   65       0  101.0      0     3          0

# %%
from sklearn.model_selection import train_test_split

# %%
x = df.drop(columns = ['has_covid'])
y = df['has_covid']

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
lr.fit(x_train , y_train)
# Out:
# LogisticRegression()

# %%
y_pred = lr.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test , y_pred)
# Out:
# 0.75

# %%
# Apply on tips data and target column placed in placement dataset

# %%
df = pd.read_csv("C:\\Users\\Anmol Hemani\\OneDrive\\Desktop\\Jupyter\\Test\\placement.csv")

# %%
df.head()
# Out:
#    cgpa  resume_score  placed
# 0  8.14          6.52       1
# 1  6.17          5.17       0
# 2  8.27          8.86       1
# 3  6.88          7.27       1
# 4  7.52          7.30       1

# %%
df.isnull().sum()
# Out:
# cgpa            0
# resume_score    0
# placed          0
# dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
x = df.drop(columns = ['placed'])
y = df['placed']

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
lr.fit(x_train , y_train)
# Out:
# LogisticRegression()

# %%
y_pred = lr.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test , y_pred)
# Out:
# 1.0

# %%
# apply on ai impact

# %%
df = pd.read_csv("C:\\Users\\Anmol Hemani\\OneDrive\\Desktop\\Jupyter\\Test\\Global_AI_Content_Impact_Dataset.csv")

# %%
df.head()
# Out:
#        Country  Year    Industry  AI Adoption Rate (%)  \
# 0  South Korea  2022       Media                 44.29
# 1        China  2025       Legal                 34.75
# 2          USA  2022  Automotive                 81.06
# 3       France  2021       Legal                 85.24
# 4       France  2021      Gaming                 78.95
#
#    AI-Generated Content Volume (TBs per year)  Job Loss Due to AI (%)  \
# 0                                       33.09                   16.77
# 1                                       66.74                   46.89
# 2                                       96.13                   10.66
# 3                                       93.76                   27.70
# 4                                       45.62                   17.45
#
#    Revenue Increase Due to AI (%)  Human-AI Collaboration Rate (%)  \
# 0                           46.12                            74.79
# 1                           52.46                            26.17
# ...

# %%
df.isnull().sum()
# Out:
# Country                                       0
# Year                                          0
# Industry                                      0
# AI Adoption Rate (%)                          0
# AI-Generated Content Volume (TBs per year)    0
# Job Loss Due to AI (%)                        0
# Revenue Increase Due to AI (%)                0
# Human-AI Collaboration Rate (%)               0
# Top AI Tools Used                             0
# Regulation Status                             0
# Consumer Trust in AI (%)                      0
# Market Share of AI Companies (%)              0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df['Country'] = le.fit_transform(df['Country'])
df['Industry'] = le.fit_transform(df['Industry'])
df['Top AI Tools Used'] = le.fit_transform(df['Top AI Tools Used'])
df['Regulation Status'] = le.fit_transform(df['Regulation Status'])

# %%
df.head()
# Out:
#    Country  Year  Industry  AI Adoption Rate (%)  \
# 0        7  2022         8                 44.29
# 1        2  2025         5                 34.75
# 2        9  2022         0                 81.06
# 3        3  2021         5                 85.24
# 4        3  2021         3                 78.95
#
#    AI-Generated Content Volume (TBs per year)  Job Loss Due to AI (%)  \
# 0                                       33.09                   16.77
# 1                                       66.74                   46.89
# 2                                       96.13                   10.66
# 3                                       93.76                   27.70
# 4                                       45.62                   17.45
#
#    Revenue Increase Due to AI (%)  Human-AI Collaboration Rate (%)  \
# 0                           46.12                            74.79
# 1                           52.46                            26.17
# ...

# %%
from sklearn.model_selection import train_test_split

# %%
x = df.drop(columns = ['Consumer Trust in AI (%)'])
y = df['Consumer Trust in AI (%)']

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train , y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test , y_pred)
# Out:
# 0.08443280786460605

# %%
# 1. Diff b/w overfitting and underfitting
# 2. what is baised variance trade-off
# 3. what is regularization technique and what is diff b/w ridge , lasso , elastic net regression

# this learning assignment done in the notebook

# %%
# 1. Polynomial Linear Regression
# 2. Regression metrics score , mae , mse , r2_score , adjusted r2_score , rmse

# this learning assignment done in the notebook

# %%
# Task done in Logistic regression on covid_toy data first run that task after that 
# for finding the best accuracy from improving the model performance 
# apply hypertuning parameter

# %% [markdown]
# # Hyperparameter Tuning

# %%
param_grid = [
    {'penalty' : ['l1','l2','elasticnet','none'],
    'C' : np.logspace(-4,4,20),
    'solver' : ['lbfgs','newton-cg','liblinear','sag','saga'],
    'max_iter' : [100,1000,2500,5000]}
]

# %%
from sklearn.model_selection import GridSearchCV

# %%
clf = GridSearchCV(lr , param_grid = param_grid, cv = 3 , verbose=True, n_jobs=-1)

# %%
# best_clf = clf.fit(x_train,y_train)

# %%
best_clf.best_estimator_
# Out:
# LogisticRegression(C=0.03359818286283781, solver='sag')

# %%
print (f'Accuracy - : {best_clf.score(x_train,y_train):.3f}')
# Out:
# Accuracy - : 0.550

# %%
# Now Apply this on titanic dataset first logistic regression then hypertuning parameter

# %%
df = pd.read_csv("C:\\Users\\Anmol Hemani\\OneDrive\\Desktop\\Jupyter\\Test\\titanic.csv")

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %%
df.isnull().sum()
# Out:
# PassengerId      0
# Survived         0
# Pclass           0
# Name             0
# Sex              0
# Age             86
# SibSp            0
# Parch            0
# Ticket           0
# Fare             1
# Cabin          327
# Embarked         0
# dtype: int64

# %%
df = df.drop(columns = ["Name","Ticket","PassengerId"])

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb = LabelEncoder()

# %%
df['Sex'] = lb.fit_transform(df['Sex'])
df['Cabin'] = lb.fit_transform(df['Cabin'])
df['Embarked'] = lb.fit_transform(df['Embarked'])

# %%
df.head()
# Out:
#    Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Cabin  Embarked
# 0         0       3    1  34.5      0      0   7.8292     76         1
# 1         1       3    0  47.0      1      0   7.0000     76         2
# 2         0       2    1  62.0      0      0   9.6875     76         1
# 3         0       3    1  27.0      0      0   8.6625     76         2
# 4         1       3    0  22.0      1      1  12.2875     76         2

# %%
from sklearn.impute import SimpleImputer

# %%
si = SimpleImputer()

# %%
df.isnull().sum()
# Out:
# Survived     0
# Pclass       0
# Sex          0
# Age         86
# SibSp        0
# Parch        0
# Fare         1
# Cabin        0
# Embarked     0
# dtype: int64

# %%
df["Age"] = si.fit_transform(df[["Age"]])
df["Cabin"] = si.fit_transform(df[["Cabin"]])

# %%
df.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        1
# Cabin       0
# Embarked    0
# dtype: int64

# %%
df["Fare"] = si.fit_transform(df[["Fare"]])

# %%
df.isnull().sum()
# Out:
# Survived    0
# Pclass      0
# Sex         0
# Age         0
# SibSp       0
# Parch       0
# Fare        0
# Cabin       0
# Embarked    0
# dtype: int64

# %%
x = df.drop(columns = ["Survived"])
y = df["Survived"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# C:\Users\Anmol Hemani\AppData\Local\Programs\Python\Python312\Lib\site-packages\sklearn\linear_model\_logistic.py:469: ConvergenceWarning: lbfgs failed to converge (status=1):
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT.
#
# Increase the number of iterations (max_iter) or scale the data as shown in:
#     https://scikit-learn.org/stable/modules/preprocessing.html
# Please also refer to the documentation for alternative solver options:
#     https://scikit-learn.org/stable/modules/linear_model.html#logistic-regression
#   n_iter_i = _check_optimize_result(
# LogisticRegression()

# %%
y_pred = lr.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test , y_pred)
# Out:
# 1.0

# %%
param_grid = [
    {'penalty' : ['l1','l2','elasticnet','none'],
    'C' : np.logspace(-4,4,20),
    'solver' : ['lbfgs','newton-cg','liblinear','sag','saga'],
    'max_iter' : [100,1000,2500,5000]}
]

# %%
from sklearn.model_selection import GridSearchCV

# %%
clf = GridSearchCV(lr , param_grid = param_grid, cv = 3 , verbose=True, n_jobs=-1)

# %%
# best_clf = clf.fit(x_train,y_train)

# %%
best_clf.best_estimator_
# Out:
# LogisticRegression(C=0.08858667904100823, penalty='l1', solver='liblinear')

# %%
print (f'Accuracy - : {best_clf.score(x_train,y_train):.3f}')
# Out:
# Accuracy - : 1.000

# %%
# Now apply this on Social data set

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\Anmol Hemani\\OneDrive\\Desktop\\Jupyter\\Test\\Social_Network_ads.csv")

# %%
df.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
df.isnull().sum()
# Out:
# User ID            0
# Gender             0
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df["Gender"] = le.fit_transform(df["Gender"])

# %%
df.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510       1   19            19000          0
# 1  15810944       1   35            20000          0
# 2  15668575       0   26            43000          0
# 3  15603246       0   27            57000          0
# 4  15804002       1   19            76000          0

# %%
x=df.drop(columns=["Purchased"])
y=df["Purchased"]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=lr.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8875

# %%
param_grid = [
    {'penalty' : ['l1','l2','elasticnet','none'],
    'C' : np.logspace(-4,4,20),
    'solver' : ['lbfgs','newton-cg','liblinear','sag','saga'],
    'max_iter' : [100,1000,2500,5000]}
]

# %%
from sklearn.model_selection import GridSearchCV

# %%
clf = GridSearchCV(lr , param_grid = param_grid, cv = 3 , verbose=True, n_jobs=-1)

# %%
# best_clf = clf.fit(x_train,y_train)

# %%
best_clf.best_estimator_
# Out:
# LogisticRegression(C=0.0006951927961775605)

# %%
print (f'Accuracy - : {best_clf.score(x_train,y_train):.3f}')
# Out:
# Accuracy - : 0.828

# %% [markdown]
# # Decision Tree

# %%
# Decision Tree => Supervised ML Model

# 1. Decision Tree Classifier => when we have target data categorical
# 2. Decision Tree Regressor => when we have targer data numerical

# %%
# decision tree working

# Gini Index
# Changes in Entropy

# d.t. = -p1log1 - p2log2 ...... -pnlogn

# %%
# Decision Tree Classifier

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\Anmol Hemani\\OneDrive\\Desktop\\Jupyter\\Test\\covid_toy.csv")

# %%
df.head()
# Out:
#    age  gender  fever cough     city has_covid
# 0   60    Male  103.0  Mild  Kolkata        No
# 1   27    Male  100.0  Mild    Delhi       Yes
# 2   42    Male  101.0  Mild    Delhi        No
# 3   31  Female   98.0  Mild  Kolkata        No
# 4   65  Female  101.0  Mild   Mumbai        No

# %%
df.isnull().sum()
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

# %%
si = SimpleImputer()

# %%
df['fever'] = si.fit_transform(df[['fever']])

# %%
df.isnull().sum()
# Out:
# age          0
# gender       0
# fever        0
# cough        0
# city         0
# has_covid    0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df['gender'] = le.fit_transform(df['gender'])
df['cough'] = le.fit_transform(df['cough'])
df['city'] = le.fit_transform(df['city'])
df['has_covid'] = le.fit_transform(df['has_covid'])

# %%
df.head()
# Out:
#    age  gender  fever  cough  city  has_covid
# 0   60       1  103.0      0     2          0
# 1   27       1  100.0      0     1          1
# 2   42       1  101.0      0     1          0
# 3   31       0   98.0      0     2          0
# 4   65       0  101.0      0     3          0

# %%
x = df.drop(columns = ['has_covid'])
y = df['has_covid']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier()

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=dt.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.55

# %%
from sklearn.model_selection import GridSearchCV

# %%
params = {
    'max_depth': [2,3,5,10,20],
    'min_samples_leaf':[5,10,20,50,100],
    'criterion':["gini","entropy"]
}

# %%
grid_search = GridSearchCV(estimator=dt,param_grid=params,
                          cv=6,n_jobs=-1,verbose=1,scoring="accuracy")

# %%
grid_search.fit(x_train,y_train)
# Out:
# Fitting 6 folds for each of 50 candidates, totalling 300 fits
# GridSearchCV(cv=6, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [2, 3, 5, 10, 20],
#                          'min_samples_leaf': [5, 10, 20, 50, 100]},
#              scoring='accuracy', verbose=1)

# %%
grid_search.best_estimator_
# Out:
# DecisionTreeClassifier(max_depth=2, min_samples_leaf=50)

# %%
y_pred_2=grid_search.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred_2)
# Out:
# 0.65

# %%
# now apply this on social network data

# %%
df = pd.read_csv("C:\\Users\\Anmol Hemani\\OneDrive\\Desktop\\Jupyter\\Test\\Social_Network_ads.csv")

# %%
df.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
df.isnull().sum()
# Out:
# User ID            0
# Gender             0
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
lb = LabelEncoder()

# %%
df['Gender']=lb.fit_transform(df['Gender'])

# %%
df.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510       1   19            19000          0
# 1  15810944       1   35            20000          0
# 2  15668575       0   26            43000          0
# 3  15603246       0   27            57000          0
# 4  15804002       1   19            76000          0

# %%
x = df.drop(columns=('Purchased'))
y=df['Purchased']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier()

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=dt.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9

# %%
from sklearn.model_selection import GridSearchCV

# %%
params = {
    'max_depth': [2,3,5,10,20],
    'min_samples_leaf':[5,10,20,50,100],
    'criterion':["gini","entropy"]
}

# %%
grid_search = GridSearchCV(estimator=dt,param_grid=params,
                          cv=6,n_jobs=-1,verbose=1,scoring="accuracy")

# %%
grid_search.fit(x_train,y_train)
# Out:
# Fitting 6 folds for each of 50 candidates, totalling 300 fits
# GridSearchCV(cv=6, estimator=DecisionTreeClassifier(), n_jobs=-1,
#              param_grid={'criterion': ['gini', 'entropy'],
#                          'max_depth': [2, 3, 5, 10, 20],
#                          'min_samples_leaf': [5, 10, 20, 50, 100]},
#              scoring='accuracy', verbose=1)

# %%
grid_search.best_estimator_
# Out:
# DecisionTreeClassifier(max_depth=2, min_samples_leaf=5)

# %%
y_pred_3=grid_search.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred_3)
# Out:
# 0.9125

# %%
# classification metrics score
#     accuracy_score , confusion metrics => true positive,true negative,false +ve,false -ve
#     precison , recall , f1_score

# %% [markdown]
# # Random Forest

# %%
# Random Forest => Supervised ML Model =>
# Ensemple method (union) => multiple base learners (Decision Tree model) =>
# 100 d.t. => 70 yes , 30 no => final prediction based on majority

# %%
import numpy as np
import pandas as pd

# %%
df = pd.read_csv("C:\\Users\\Anmol Hemani\\OneDrive\\Desktop\\Jupyter\\Test\\Social_Network_ads.csv")

# %%
df.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510    Male   19            19000          0
# 1  15810944    Male   35            20000          0
# 2  15668575  Female   26            43000          0
# 3  15603246  Female   27            57000          0
# 4  15804002    Male   19            76000          0

# %%
df.isnull().sum()
# Out:
# User ID            0
# Gender             0
# Age                0
# EstimatedSalary    0
# Purchased          0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df['Gender']=le.fit_transform(df['Gender'])

# %%
df.head()
# Out:
#     User ID  Gender  Age  EstimatedSalary  Purchased
# 0  15624510       1   19            19000          0
# 1  15810944       1   35            20000          0
# 2  15668575       0   26            43000          0
# 3  15603246       0   27            57000          0
# 4  15804002       1   19            76000          0

# %%
x = df.drop(columns=('Purchased'))
y=df['Purchased']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = lr.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.8875

# %%
# Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dt = DecisionTreeClassifier()

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred=dt.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9

# %%
# Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rf = RandomForestClassifier()

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = rf.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.925

# %%
# now apply this on covid data

# %%
df = pd.read_csv("C:\\Users\\Anmol Hemani\\OneDrive\\Desktop\\Jupyter\\Test\\covid_toy.csv")

# %%
df.head()
# Out:
#    age  gender  fever cough     city has_covid
# 0   60    Male  103.0  Mild  Kolkata        No
# 1   27    Male  100.0  Mild    Delhi       Yes
# 2   42    Male  101.0  Mild    Delhi        No
# 3   31  Female   98.0  Mild  Kolkata        No
# 4   65  Female  101.0  Mild   Mumbai        No

# %%
df.isnull().sum()
# Out:
# age           0
# gender        0
# fever        10
# cough         0
# city          0
# has_covid     0
# dtype: int64

# %%
from sklearn.impute import SimpleImputer

# %%
si = SimpleImputer()

# %%
df['fever']=si.fit_transform(df[['fever']])

# %%
df.isnull().sum()
# Out:
# age          0
# gender       0
# fever        0
# cough        0
# city         0
# has_covid    0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df['gender'] = le.fit_transform(df['gender'])
df['cough'] = le.fit_transform(df['cough'])
df['city'] = le.fit_transform(df['city'])
df['has_covid'] = le.fit_transform(df['has_covid'])

# %%
df.head()
# Out:
#    age  gender  fever  cough  city  has_covid
# 0   60       1  103.0      0     2          0
# 1   27       1  100.0      0     1          1
# 2   42       1  101.0      0     1          0
# 3   31       0   98.0      0     2          0
# 4   65       0  101.0      0     3          0

# %%
x=df.drop(columns = ['has_covid'])
y=df['has_covid']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
# Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression

# %%
lr = LogisticRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred = lr.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.75

# %%
# Decision Tree Classifier

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
dtc = DecisionTreeClassifier()

# %%
dtc.fit(x_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
y_pred = dtc.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.4

# %%
# Random Forest Classifier

# %%
from sklearn.ensemble import RandomForestClassifier

# %%
rc = RandomForestClassifier()

# %%
rc.fit(x_train,y_train)
# Out:
# RandomForestClassifier()

# %%
y_pred = rc.predict(x_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.45

# %%
# Insurance Dataset =>
# LinearRegression, decisiontreeregressor, randomfirestregressor => metrics(r2_score)

# %%
df = pd.read_csv("C:\\Users\\Anmol Hemani\\OneDrive\\Desktop\\Jupyter\\Test\\insurance.csv")

# %%
df.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %%
df.isnull().sum()
# Out:
# age         0
# sex         0
# bmi         0
# children    0
# smoker      0
# region      0
# charges     0
# dtype: int64

# %%
from sklearn.preprocessing import LabelEncoder

# %%
le = LabelEncoder()

# %%
df['sex'] = le.fit_transform(df['sex'])
df['smoker'] = le.fit_transform(df['smoker'])
df['region'] = le.fit_transform(df['region'])

# %%
df.head()
# Out:
#    age  sex     bmi  children  smoker  region      charges
# 0   19    0  27.900         0       1       3  16884.92400
# 1   18    1  33.770         1       0       2   1725.55230
# 2   28    1  33.000         3       0       2   4449.46200
# 3   33    1  22.705         0       0       1  21984.47061
# 4   32    1  28.880         0       0       1   3866.85520

# %%
x = df.drop(columns = ['charges'])
y = df['charges']

# %%
from sklearn.model_selection import train_test_split

# %%
x_train , x_test , y_train , y_test = train_test_split(x,y,test_size=0.2,random_state=42)

# %%
# Linear Regression

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()

# %%
lr.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=lr.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.7833463107364539

# %%
# Decision Tree Regressor

# %%
from sklearn.tree import DecisionTreeRegressor

# %%
dt = DecisionTreeRegressor()

# %%
dt.fit(x_train,y_train)
# Out:
# DecisionTreeRegressor()

# %%
y_pred=dt.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.7329191880614383

# %%
# Random Forest Regressor

# %%
from sklearn.ensemble import RandomForestRegressor

# %%
rf = RandomForestRegressor()

# %%
rf.fit(x_train,y_train)
# Out:
# RandomForestRegressor()

# %%
y_pred = rf.predict(x_test)

# %%
from sklearn.metrics import r2_score

# %%
r2_score(y_test,y_pred)
# Out:
# 0.8622555785893908
